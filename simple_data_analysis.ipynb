# %% [markdown]
# # Day 1 Assignment: Simple Data Analysis
# ## Wholesale Customers Dataset

# %% [markdown]
# ## 1. Data Loading

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('Wholesale_Customers_Data.csv')
print("Dataset loaded!")
print(f"Shape: {df.shape}")
# Out:
# Dataset loaded!
# Shape: (440, 8)

# %%
# Show first 5 rows
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %% [markdown]
# ## 2. Data Cleaning

# %%
# Check for missing values
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# Total_Spending      0
# dtype: int64

# %%
# Check data types
print("Data types:")
print(df.dtypes)
# Out:
# Data types:
# Channel             int64
# Region              int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %%
# Basic statistics
df.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# 25%      742.250000        256.750000    408.250000
# 50%     1526.000000        816.500000    965.500000
# 75%     3554.250000       3922.000000   1820.250000
# max    60869.000000      40827.000000  47943.000000

# %% [markdown]
# ## 3. Simple Transformations

# %%
# Create new feature: Total Spending
df['Total_Spending'] = df['Fresh'] + df['Milk'] + df['Grocery'] + df['Frozen'] + df['Detergents_Paper'] + df['Delicassen']
print("New feature created: Total_Spending")
print(f"Average total spending: {df['Total_Spending'].mean():.0f}")
# Out:
# New feature created: Total_Spending
# Average total spending: 33226

# %% [markdown]
# ## 4. Visualization 1: Distribution of Fresh Products

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Fresh'], bins=20, color='green', alpha=0.7)
plt.title('Distribution of Fresh Product Spending')
plt.xlabel('Fresh Product Spending')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ## 5. Visualization 2: Fresh vs Milk Spending

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Fresh'], df['Milk'], alpha=0.6, color='blue')
plt.title('Fresh vs Milk Product Spending')
plt.xlabel('Fresh Product Spending')
plt.ylabel('Milk Product Spending')
plt.show()

# %% [markdown]
# ## 6. Visualization 3: Channel Distribution

# %%
plt.figure(figsize=(6, 6))
channel_counts = df['Channel'].value_counts()
plt.pie(channel_counts.values, labels=['Retail', 'Hotel/Restaurant'], autopct='%1.1f%%')
plt.title('Customer Channel Distribution')
plt.show()

# %% [markdown]
# ## 7. Summary

# %%
print("Analysis Summary:")
print(f"Total customers: {len(df)}")
print(f"No missing values found")
print(f"Average total spending: {df['Total_Spending'].mean():.0f}")
print(f"Channel 1 customers: {(df['Channel'] == 1).sum()}")
print(f"Channel 2 customers: {(df['Channel'] == 2).sum()}")
# Out:
# Analysis Summary:
# Total customers: 440
# No missing values found
# Average total spending: 33226
# Channel 1 customers: 298
# Channel 2 customers: 142
